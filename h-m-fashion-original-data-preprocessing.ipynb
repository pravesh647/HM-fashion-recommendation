# %% [markdown]
# ### Data Description
#
# **articles.csv** - detailed metadata for each article_id available for purchase
# <br>
# **customers.csv** - metadata for each customer_id in dataset
# <br>
# **sample_submission.csv** - a sample submission file in the correct format
# <br>
# **transactions_train.csv** - the training data, consisting of the purchases each customer for each date, as well as additional information. Duplicate rows correspond to multiple purchases of the same item. Your task is to predict the article_ids each customer will purchase during the 7-day period immediately after the training data period.
#
# [Data Link to Kaggle](https://www.kaggle.com/competitions/h-and-m-personalized-fashion-recommendations/data)

# %% [markdown]
# ### Brainstorming
#
# **How to recommend an article to a customer A?**
#
# *Recommendation based on siimilar customer taste*
# - If A bought 5 articles in the past, and 100 other customers bought the same articles, we can cluster these customers together.
# - take a popularity list of articles bought by these other 100 customers but not bought by A in a descending order
# - recommend the most popular articles amaong the 100 other customers to A
#
# *Recommendation based on customer taste, unrelated to other customers*
# - if a customer bought 5 items in the past,
# - could we use extensive customer data to create customer personas where each persona represents a style?
# - use text prediction LSTM?

# %% [markdown]
# ## Import Data

# %%
# linear algebra
import numpy as np
import pandas as pd

import tensorflow.keras as keras
from tensorflow.keras import layers

# ML Framework
from keras.models import Sequential
from keras.layers import Dense, Activation

# Visualization
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# importing training and test data
trans_df = pd.read_csv("../hm_data/transactions_train.csv")

# %%
article_df = pd.read_csv("../hm_data/articles.csv")

# %%
cust_df = pd.read_csv("../hm_data/customers.csv")

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# There is too much data for initial modelling.
#
# **Pseudo code:**
# 1. Get the popularity list (pop_list) for articles: decided by the no of times an article is bought
#     - count for the unique article_id in the trans_df in descending order, so first article is most popular
# 2. Merge the popularity list into the article_df. the article_df will have an additional column named popularity
# 3. Sort the article_df based on popularity
# 4. The most popular articles are espected to be common regular use articles such as socks, underwear etc. We want to throw away these data points. Look at article_df with human eye and distinguish where the common articles end
#
#
#
# <br>
# 3. Take the 10000 most popular articles (top). top 10k of the pop_list
# 4. throw away data not related to top 10000 popular articles from both trans_df and article_df
# 5.
#
#
# We take the data for
#
#
# **Extra:**
# - should I convert the candidate_id to something more manageable?
# -

# %%
# pop_list = popularity list for articles
# counts the unique values in article_id and gives a series in descending order
pop_list = trans_df["article_id"].value_counts()
# series to df
pop_list = pop_list.to_frame()
pop_list = pop_list.rename(columns={"article_id":"popularity"})
pop_list = pop_list.reset_index()
pop_list = pop_list.rename(columns={"index": "article_id"})
pop_list
# Out:
#         article_id  popularity
# 0        706016001       50287
# 1        706016002       35043
# 2        372860001       31718
# 3        610776002       30199
# 4        759871002       26329
# ...            ...         ...
# 104542   520736002           1
# 104543   619777003           1
# 104544   586904003           1
# 104545   512385003           1
# 104546   533261032           1
#
# [104547 rows x 2 columns]

# %%
# Merge pop_list to article_df. Below code throws away rows in article_df that do not have a common key in pop_list
article_df = pd.merge(article_df, pop_list, on="article_id")
# Now we have an article_df with a popularity count for each article

# %%
# sorting article_df in descending order based on popularity column
article_df = article_df.sort_values(by=["popularity"], ascending= False)

# %%
article_df
# Out:
#        article_id  product_code                 prod_name  product_type_no  \
# 53832   706016001        706016  Jade HW Skinny Denim TRS              272
# 53833   706016002        706016  Jade HW Skinny Denim TRS              272
# 1711    372860001        372860        7p Basic Shaftless              302
# 24808   610776002        610776                 Tilly (1)              255
# 70124   759871002        759871                Tilda tank              253
# ...           ...           ...                       ...              ...
# 8205    521266001        521266            Patsy PU Glove               71
# 36666   651538001        651538  Sigge leather helmet bag               66
# 8211    521302001        521302        Make the boys wink              252
# 36710   651645003        651645                HARIBO TEE              255
# 13340   557727001        557727                  Fagan SS              259
#
#       product_type_name  product_group_name  graphical_appearance_no  \
# 53832          Trousers  Garment Lower body                  1010016
# 53833          Trousers  Garment Lower body                  1010016
# 1711              Socks      Socks & Tights                  1010016
# 24808           T-shirt  Garment Upper body                  1010016
# 70124          Vest top  Garment Upper body                  1010016
# ...                 ...                 ...                      ...
# 8205             Gloves         Accessories                  1010016
# 36666               Bag         Accessories                  1010016
# 8211            Sweater  Garment Upper body                  1010010
# 36710           T-shirt  Garment Upper body                  1010005
# 13340             Shirt  Garment Upper body                  1010024
#
#       graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 53832                     Solid                  9             Black  ...
# 53833                     Solid                 71        Light Blue  ...
# 1711                      Solid                  9             Black  ...
# 24808                     Solid                  9             Black  ...
# 70124                     Solid                  9             Black  ...
# ...                         ...                ...               ...  ...
# 8205                      Solid                  9             Black  ...
# 36666                     Solid                 17   Yellowish Brown  ...
# 8211                    Melange                 23       Dark Yellow  ...
# 36710           Colour blocking                 91       Light Green  ...
# 13340                  Chambray                 72              Blue  ...
#
#        index_code          index_name  index_group_no index_group_name  \
# 53832           D             Divided               2          Divided
# 53833           D             Divided               2          Divided
# 1711            B    Lingeries/Tights               1       Ladieswear
# 24808           A          Ladieswear               1       Ladieswear
# 70124           D             Divided               2          Divided
# ...           ...                 ...             ...              ...
# 8205            C  Ladies Accessories               1       Ladieswear
# 36666           F            Menswear               3         Menswear
# 8211            A          Ladieswear               1       Ladieswear
# 36710           F            Menswear               3         Menswear
# 13340           F            Menswear               3         Menswear
#
#        section_no                    section_name garment_group_no  \
# 53832          53              Divided Collection             1009
# 53833          53              Divided Collection             1009
# 1711           62  Womens Nightwear, Socks & Tigh             1021
# 24808          16          Womens Everyday Basics             1002
# 70124          80       Divided Complements Other             1002
# ...           ...                             ...              ...
# 8205           65          Womens Big accessories             1019
# 36666          25                 Men Accessories             1019
# 8211           15      Womens Everyday Collection             1003
# 36710          20              Contemporary Smart             1005
# 13340          20              Contemporary Smart             1011
#
#       garment_group_name                                        detail_desc  \
# 53832           Trousers  High-waisted jeans in washed superstretch deni...
# 53833           Trousers  High-waisted jeans in washed superstretch deni...
# 1711    Socks and Tights    Fine-knit trainer socks in a soft cotton blend.
# 24808       Jersey Basic  T-shirt in lightweight jersey with a rounded h...
# 70124       Jersey Basic  Cropped, fitted top in cotton jersey with narr...
# ...                  ...                                                ...
# 8205         Accessories   Gloves in soft, supple imitation leather. Lined.
# 36666        Accessories  Leather bag with two handles and a zip at the ...
# 8211            Knitwear  Wide jumper in a soft rib knit containing some...
# 36710       Jersey Fancy              Block-print T-shirt in cotton jersey.
# 13340             Shirts  Short-sleeved shirt in stretch cotton chambray...
#
#       popularity
# 53832      50287
# 53833      35043
# 1711       31718
# 24808      30199
# 70124      26329
# ...          ...
# 8205           1
# 36666          1
# 8211           1
# 36710          1
# 13340          1
#
# [104547 rows x 26 columns]

# %%
article_df[article_df["product_group_name"] == "Socks & Tights"]
# Out:
#        article_id  product_code                   prod_name  product_type_no  \
# 1711    372860001        372860          7p Basic Shaftless              302
# 1712    372860002        372860          7p Basic Shaftless              302
# 67      156231001        156231               Box 4p Tights              304
# 24237   608776002        608776            Scallop 5p Socks              302
# 74      160442007        160442            3p Sneaker Socks              302
# ...           ...           ...                         ...              ...
# 14448   562990013        562990         Billie 10-p sock BG              302
# 14402   562734022        562734        Liseberg 5-p sock BG              302
# 14401   562734021        562734        Liseberg 5-p sock BG              302
# 781     293433012        293433  2-p basic cotton tights SG              304
# 65602   745256004        745256             Bosse 5-pack OL              302
#
#       product_type_name product_group_name  graphical_appearance_no  \
# 1711              Socks     Socks & Tights                  1010016
# 1712              Socks     Socks & Tights                  1010016
# 67     Underwear Tights     Socks & Tights                  1010016
# 24237             Socks     Socks & Tights                  1010016
# 74                Socks     Socks & Tights                  1010016
# ...                 ...                ...                      ...
# 14448             Socks     Socks & Tights                  1010016
# 14402             Socks     Socks & Tights                  1010013
# 14401             Socks     Socks & Tights                  1010013
# 781    Underwear Tights     Socks & Tights                  1010016
# 65602             Socks     Socks & Tights                  1010001
#
#       graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 1711                      Solid                  9             Black  ...
# 1712                      Solid                 10             White  ...
# 67                        Solid                  9             Black  ...
# 24237                     Solid                  9             Black  ...
# 74                        Solid                  9             Black  ...
# ...                         ...                ...               ...  ...
# 14448                     Solid                  7              Grey  ...
# 14402             Other pattern                  7              Grey  ...
# 14401             Other pattern                  8         Dark Grey  ...
# 781                       Solid                 43          Dark Red  ...
# 65602          All over pattern                 72              Blue  ...
#
#        index_code              index_name  index_group_no index_group_name  \
# 1711            B        Lingeries/Tights               1       Ladieswear
# 1712            B        Lingeries/Tights               1       Ladieswear
# 67              B        Lingeries/Tights               1       Ladieswear
# 24237           B        Lingeries/Tights               1       Ladieswear
# 74              B        Lingeries/Tights               1       Ladieswear
# ...           ...                     ...             ...              ...
# 14448           I  Children Sizes 134-170               4    Baby/Children
# 14402           I  Children Sizes 134-170               4    Baby/Children
# 14401           I  Children Sizes 134-170               4    Baby/Children
# 781             H   Children Sizes 92-140               4    Baby/Children
# 65602           G        Baby Sizes 50-98               4    Baby/Children
#
#        section_no                    section_name garment_group_no  \
# 1711           62  Womens Nightwear, Socks & Tigh             1021
# 1712           62  Womens Nightwear, Socks & Tigh             1021
# 67             62  Womens Nightwear, Socks & Tigh             1021
# 24237          62  Womens Nightwear, Socks & Tigh             1021
# 74             62  Womens Nightwear, Socks & Tigh             1021
# ...           ...                             ...              ...
# 14448          79        Girls Underwear & Basics             1021
# 14402          79        Girls Underwear & Basics             1021
# 14401          79        Girls Underwear & Basics             1021
# 781            79        Girls Underwear & Basics             1021
# 65602          44   Baby Essentials & Complements             1021
#
#       garment_group_name                                        detail_desc  \
# 1711    Socks and Tights    Fine-knit trainer socks in a soft cotton blend.
# 1712    Socks and Tights    Fine-knit trainer socks in a soft cotton blend.
# 67      Socks and Tights  Matt tights with an elasticated waist. 20 denier.
# 24237   Socks and Tights             Fine-knit socks with a scalloped edge.
# 74      Socks and Tights  Short, fine-knit socks designed to be hidden b...
# ...                  ...                                                ...
# 14448   Socks and Tights  Fine-knit socks in a cotton blend with elastic...
# 14402   Socks and Tights  Jacquard-knit socks in a soft cotton blend in ...
# 14401   Socks and Tights  Jacquard-knit socks in a soft cotton blend in ...
# 781     Socks and Tights  Tights in a soft, fine knit with an elasticate...
# 65602   Socks and Tights  Socks in a soft, jacquard-knit cotton blend wi...
#
#       popularity
# 1711       31718
# 1712       24458
# 67         21013
# 24237      17886
# 74         17866
# ...          ...
# 14448          1
# 14402          1
# 14401          1
# 781            1
# 65602          1
#
# [2420 rows x 26 columns]

# %%
article_df["product_group_name"].value_counts().to_frame()
# Out:
#                        product_group_name
# Garment Upper body                  42313
# Garment Lower body                  19661
# Garment Full body                   13160
# Accessories                         11023
# Underwear                            5447
# Shoes                                5228
# Swimwear                             3127
# Socks & Tights                       2420
# Nightwear                            1882
# Unknown                               113
# Underwear/nightwear                    53
# Cosmetic                               48
# Bags                                   25
# Items                                  15
# Furniture                              13
# Garment and Shoe care                   9
# Stationery                              5
# Interior textile                        3
# Fun                                     2

# %%
len(article_df)
# Out:
# 104547

# %% [markdown]
# pop_list = list(pop_list.index.values)

# %% [markdown]
# top = top[:10000]

# %%
trans_df[trans_df['article_id'].isin(top)]

# %%
len(article_df)
# Out:
# 105542

# %%
article_df[article_df['article_id'].isin(top)]
# Out:
#         article_id  product_code                  prod_name  product_type_no  \
# 58       153115020        153115              OP Strapless^              306
# 186      189626001        189626                 Jodi skirt              275
# 230      201219001        201219     Heavy plain 2 p tights              304
# 261      212629004        212629        Alcazar strap dress              265
# 505      253448002        253448         OP Push Melbourne^              306
# ...            ...           ...                        ...              ...
# 97827    876053003        876053                       Ruby              258
# 98422    879248001        879248                   Glamping              274
# 98796    880839001        880839       Eleonor button dress              265
# 99169    882888002        882888            Agneta jumpsuit              272
# 104045   918292001        918292  STRONG HW seamless tights              273
#
#        product_type_name  product_group_name  graphical_appearance_no  \
# 58                   Bra           Underwear                  1010016
# 186                Skirt  Garment Lower body                  1010016
# 230     Underwear Tights      Socks & Tights                  1010016
# 261                Dress   Garment Full body                  1010016
# 505                  Bra           Underwear                  1010016
# ...                  ...                 ...                      ...
# 97827             Blouse  Garment Upper body                  1010001
# 98422             Shorts  Garment Lower body                  1010016
# 98796              Dress   Garment Full body                  1010016
# 99169           Trousers  Garment Lower body                  1010017
# 104045   Leggings/Tights  Garment Lower body                  1010010
#
#        graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 58                         Solid                 12       Light Beige  ...
# 186                        Solid                  9             Black  ...
# 230                        Solid                  9             Black  ...
# 261                        Solid                  9             Black  ...
# 505                        Solid                 10             White  ...
# ...                          ...                ...               ...  ...
# 97827           All over pattern                 92             Green  ...
# 98422                      Solid                  9             Black  ...
# 98796                      Solid                  9             Black  ...
# 99169                     Stripe                 12       Light Beige  ...
# 104045                   Melange                  9             Black  ...
#
#              department_name index_code        index_name index_group_no  \
# 58            Clean Lingerie          B  Lingeries/Tights              1
# 186                  Basic 1          D           Divided              2
# 230             Tights basic          B  Lingeries/Tights              1
# 261                  Basic 1          D           Divided              2
# 505           Clean Lingerie          B  Lingeries/Tights              1
# ...                      ...        ...               ...            ...
# 97827                 Blouse          A        Ladieswear              1
# 98422           Jersey Basic          A        Ladieswear              1
# 98796                Basic 1          D           Divided              2
# 99169           Jersey fancy          A        Ladieswear              1
# 104045  Ladies Sport Bottoms          S             Sport             26
#
#         index_group_name section_no                    section_name  \
# 58            Ladieswear         61                 Womens Lingerie
# 186              Divided         51                  Divided Basics
# 230           Ladieswear         62  Womens Nightwear, Socks & Tigh
# 261              Divided         51                  Divided Basics
# 505           Ladieswear         61                 Womens Lingerie
# ...                  ...        ...                             ...
# 97827         Ladieswear         15      Womens Everyday Collection
# 98422         Ladieswear         16          Womens Everyday Basics
# 98796            Divided         51                  Divided Basics
# 99169         Ladieswear         15      Womens Everyday Collection
# 104045             Sport          5                Ladies H&M Sport
#
#        garment_group_no  garment_group_name  \
# 58                 1017   Under-, Nightwear
# 186                1002        Jersey Basic
# 230                1021    Socks and Tights
# 261                1002        Jersey Basic
# 505                1017   Under-, Nightwear
# ...                 ...                 ...
# 97827              1010             Blouses
# 98422              1002        Jersey Basic
# 98796              1002        Jersey Basic
# 99169              1005        Jersey Fancy
# 104045             1005        Jersey Fancy
#
#                                               detail_desc
# 58      Strapless bra in microfibre with underwired, p...
# 186     Short, bell-shaped skirt in stretch jersey wit...
# 230           Fine-knit tights with an elasticated waist.
# 261     Long, sleeveless dress in jersey with narrow s...
# 505     Push-up bra in microfibre with underwired, mou...
# ...                                                   ...
# 97827   Blouse in a crêpe weave with a sweetheart neck...
# 98422   Short shorts in lightweight sweatshirt fabric ...
# 98796   Calf-length dress in ribbed jersey with a V-ne...
# 99169   Ankle-length jumpsuit in airy jersey crêpe wit...
# 104045  Sports tights in fast-drying functional fabric...
#
# [500 rows x 25 columns]

# %%
len(cust_df)
# Out:
# 1371980
